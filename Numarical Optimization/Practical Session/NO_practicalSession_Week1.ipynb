# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# price = m * size  + c
x_data = np.array([1,2,3,4,5,6,7,8])
y_data = np.array([2.1, 3.9, 6.2, 7.8, 10.1, 12.3, 14.0, 15.8])

coeffs = np.polyfit(x_data, y_data, 1)

x_line = np.linspace(1, 8, 1000)
y_line = coeffs[0] * x_line + coeffs[1]
plt.figure(figsize = (8,6))
plt.scatter(x_data, y_data,
color = 'blue', s = 80, alpha = 0.7)
plt.plot(x_line, y_line, color='green', linewidth=2, label = 'Model Line')
plt.legend()
plt.grid(True, alpha=0.2)
plt.show()

# %%
'''# Python Code: Scatter Plot with Model Line
# import matplotlib.pyplot as plt
# import numpy as np
#Sample data
x = np.array([1, 2, 3, 4, 5, 6, 7,8])
y = np.array([2.1, 3.9, 6.2, 7.8, 10.1, 12.3, 14.0, 15.8])
#Create model line (linear fit)
coeffs = np.polyfit(x, y, 1)
x_line = np.linspace (1, 8, 100)
y_line = coeffs [0] * x_line + coeffs [1]
# Create the plot
plt.figure(figsize=(8,6))
plt.scatter(x, y, color = 'blue',s=80, alpha=0.8, label = 'Data Points')
plt.plot(x_line, y_line, color='green', linewidth=2, label='Model Line')
# Add labels and formatting
plt.xlabel('X Values', fontsize=12)
plt.ylabel('Y Values', fontsize=12)
plt.title('Scatter Plot with Linear Model', fontsize=14)
plt.legend()
plt.grid(True, alpha=0.2)
plt.show()'''
# Out:
# "# Python Code: Scatter Plot with Model Line\n# import matplotlib.pyplot as plt\n# import numpy as np\n#Sample data\nx = np.array([1, 2, 3, 4, 5, 6, 7,8])\ny = np.array([2.1, 3.9, 6.2, 7.8, 10.1, 12.3, 14.0, 15.8])\n#Create model line (linear fit)\ncoeffs = np.polyfit(x, y, 1)\nx_line = np.linspace (1, 8, 100)\ny_line = coeffs [0] * x_line + coeffs [1]\n# Create the plot\nplt.figure(figsize=(8,6))\nplt.scatter(x, y, color = 'blue',s=80, alpha=0.8, label = 'Data Points')\nplt.plot(x_line, y_line, color='green', linewidth=2, label='Model Line')\n# Add labels and formatting\nplt.xlabel('X Values', fontsize=12)\nplt.ylabel('Y Values', fontsize=12)\nplt.title('Scatter Plot with Linear Model', fontsize=14)\nplt.legend()\nplt.grid(True, alpha=0.2)\nplt.show()"

# %%
# Create a vector which shows Study hours in a week of multiple matrix

# %%
# x : students
# y : study hours

x_student = 4
y_study = np.random.randint(0, 10, size = (x_student))
print(y_study)
# Out:
# [8 6 2 0]

# %%
y_study.shape
# Out:
# (4,)

# %%
# x = np.arange(-10, 11)
x = np.linspace(-10, 10, 1000)
y = x**2

plt.plot(x, y, label = "y = x^2")
plt.legend()
plt.grid(True)
plt.show()

# %%
x = np.arange(0, 10)
# x = np.linspace(-10, 10, 1000)
y = x**2

plt.plot(x, y, label = "y = x^2")
plt.legend()
plt.grid(True)
plt.show()

# %%
# x = np.arange(1, 10)
x = np.linspace(0, 10, 1000)
y = x**2

plt.plot(x, y, label = "y = x^2")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
maths = [60, 70, 80, 90, 100]
science = [65, 68, 78, 85, 95]

plt.scatter(maths, science)
plt.grid(True)
plt.show()

# %%
index = [1, 2, 3, 4, 5]
maths = [60, 70, 80, 90, 100]
science = [65, 68, 78, 85, 95]

plt.scatter(index, science)
plt.scatter(index, maths)
plt.grid(True)
plt.show()

# %%
# Now we can compare

# %%
size = np.array([650, 800, 1200, 1500, 2000])
prices = np.array([50, 70, 110, 140, 200])

scatterPlot = plt.scatter(size, prices, label="data")

m, c = 0.108, -19.97
line = m*size + c
plt.plot(size, line, color = "green", label="our hints")
plt.legend()
plt.show()
