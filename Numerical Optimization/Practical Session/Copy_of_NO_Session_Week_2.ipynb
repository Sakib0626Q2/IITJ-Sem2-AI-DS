# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and its gradient
def f(x):
  return x**2

def grad(x):
  return 2*x

# Parameters
x = -7 # starting point
learning_rate = 0.05
steps = 20

history = [x]

#Gradient Descent Loop
for i in range(steps):
  slope = grad(x)
  x = x - learning_rate * slope
  history.append(x)

# PLot fuction and steps
x_vals = np.linspace(-10,10,200)
y_vals = f(x_vals)

plt.plot(x_vals, y_vals, label="y=x^2")
plt.scatter(history, [f(i) for i in history], color="red", label="Steps")
plt.legend()
plt.show()

# %%
# try starting points x=10 & x=-7
# try different learning rates 0.01 & 0.5
# what happens when slope is zero

# %%
# take equation f(x) = (x-5)**2 + 3

# %%
## Plot multiple lines

x = [ 1, 2, 3, 4, 5]
y1 = [1, 4, 9, 16, 25]
y2 = [1, 2, 3, 4, 5]
y3 = [25, 25, 15, 10, 5]

plt.plot(x, y1, label="Model-A")
plt.plot(x, y2, label="Model-B")
plt.plot(x, y3, label="Model-C")

plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
plt.title("Multiple Models Comparison")
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return (x-3)**2 + 1

def df_dx(x):
    return 2 * (x-3)

x_start = 0.5
learning_rate = 0.1  # Set learning rate
iterations = 50  # Set the number of iterations

x = x_start
x_history = [x]
y_history = [f(x)]

# Initialize the plot
plt.figure(figsize=(8, 6))

# Create x values for plotting the function curve
x_plot = np.linspace(-1, 6, 100)
y_plot = f(x_plot)
plt.plot(x_plot, y_plot, label=r"$f(x) = (x-3)^2 + 1$", color='blue')

for i in range(iterations):
    gradient = df_dx(x)
    x = x - learning_rate * gradient  # Update x using the gradient
    x_history.append(x)
    y_history.append(f(x))

    print(f"step {i+1}: x = {x:.3f}, f(x) = {f(x):.3f}, gradient: {gradient}")

    # Plot current position of x
    plt.scatter(x, f(x), color='red', zorder=5)
    plt.plot(x_history, y_history, color='green', linestyle='--', alpha=0.5)

# Customize plot appearance
plt.title("Gradient Descent on $f(x) = (x-3)^2 + 1$")
plt.xlabel("x")
plt.ylabel("f(x)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# step 1: x = 1.000, f(x) = 5.000, gradient: -5.0
# step 2: x = 1.400, f(x) = 3.560, gradient: -4.0
# step 3: x = 1.720, f(x) = 2.638, gradient: -3.2
# step 4: x = 1.976, f(x) = 2.049, gradient: -2.56
# step 5: x = 2.181, f(x) = 1.671, gradient: -2.048
# step 6: x = 2.345, f(x) = 1.429, gradient: -1.6383999999999999
# step 7: x = 2.476, f(x) = 1.275, gradient: -1.3107199999999999
# step 8: x = 2.581, f(x) = 1.176, gradient: -1.0485759999999997
# step 9: x = 2.664, f(x) = 1.113, gradient: -0.8388608
# step 10: x = 2.732, f(x) = 1.072, gradient: -0.6710886399999998
# step 11: x = 2.785, f(x) = 1.046, gradient: -0.5368709119999995
# step 12: x = 2.828, f(x) = 1.030, gradient: -0.4294967295999994
# step 13: x = 2.863, f(x) = 1.019, gradient: -0.3435973836799997
# step 14: x = 2.890, f(x) = 1.012, gradient: -0.27487790694399994
# step 15: x = 2.912, f(x) = 1.008, gradient: -0.21990232555519995
# step 16: x = 2.930, f(x) = 1.005, gradient: -0.17592186044416014
# step 17: x = 2.944, f(x) = 1.003, gradient: -0.1407374883553283
# step 18: x = 2.955, f(x) = 1.002, gradient: -0.11258999068426245
# step 19: x = 2.964, f(x) = 1.001, gradient: -0.09007199254740961
# step 20: x = 2.971, f(x) = 1.001, gradient: -0.07205759403792733
# step 21: x = 2.977, f(x) = 1.001, gradient: -0.05764607523034204
# step 22: x = 2.982, f(x) = 1.000, gradient: -0.046116860184273634
# step 23: x = 2.985, f(x) = 1.000, gradient: -0.03689348814741855
# step 24: x = 2.988, f(x) = 1.000, gradient: -0.029514790517934486
# step 25: x = 2.991, f(x) = 1.000, gradient: -0.023611832414347944
# step 26: x = 2.992, f(x) = 1.000, gradient: -0.018889465931478
# step 27: x = 2.994, f(x) = 1.000, gradient: -0.015111572745182045
# step 28: x = 2.995, f(x) = 1.000, gradient: -0.012089258196145813
# step 29: x = 2.996, f(x) = 1.000, gradient: -0.009671406556917006
# step 30: x = 2.997, f(x) = 1.000, gradient: -0.007737125245533605
# step 31: x = 2.998, f(x) = 1.000, gradient: -0.0061897001964270615
# step 32: x = 2.998, f(x) = 1.000, gradient: -0.004951760157141827
# step 33: x = 2.998, f(x) = 1.000, gradient: -0.003961408125713106
# step 34: x = 2.999, f(x) = 1.000, gradient: -0.0031691265005706626
# step 35: x = 2.999, f(x) = 1.000, gradient: -0.00253530120045653
# step 36: x = 2.999, f(x) = 1.000, gradient: -0.0020282409603655793
# step 37: x = 2.999, f(x) = 1.000, gradient: -0.0016225927682924635
# step 38: x = 2.999, f(x) = 1.000, gradient: -0.0012980742146337931
# step 39: x = 3.000, f(x) = 1.000, gradient: -0.0010384593717072121
# step 40: x = 3.000, f(x) = 1.000, gradient: -0.0008307674973657697
# step 41: x = 3.000, f(x) = 1.000, gradient: -0.000664613997892971
# step 42: x = 3.000, f(x) = 1.000, gradient: -0.0005316911983141992
# step 43: x = 3.000, f(x) = 1.000, gradient: -0.000425352958651537
# step 44: x = 3.000, f(x) = 1.000, gradient: -0.00034028236692140723
# step 45: x = 3.000, f(x) = 1.000, gradient: -0.00027222589353748106
# step 46: x = 3.000, f(x) = 1.000, gradient: -0.0002177807148298072
# step 47: x = 3.000, f(x) = 1.000, gradient: -0.00017422457186366813
# step 48: x = 3.000, f(x) = 1.000, gradient: -0.00013937965749111214
# step 49: x = 3.000, f(x) = 1.000, gradient: -0.00011150372599288971
# step 50: x = 3.000, f(x) = 1.000, gradient: -8.92029807939565e-05
