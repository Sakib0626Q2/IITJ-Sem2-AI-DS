# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "MD Sakib"
COLLABORATORS = "MD Sakib"

# %% [markdown]
# ---

# %% [markdown]
# # Assignment 1 — Student Performance Analysis(15 points)
# Please read all instructions carefully before starting this assignment.
#
# General Instructions:
# - Use the file student_performance.csv provided in this assignment folder.
# - Do not rename or modify the CSV file or its contents.
# - Each question specifies exact variable names you must use (e.g., mean_score, correlation_study_exam, etc.). These names are required for automatic grading.
# - Incorrect or misspelled variable names may cause your answers to fail the autograder.
# - You cannot edit the instruction or setup cells.
# - Write your code only inside the cells marked as “Your Code Here.”
# - Do not modify or delete any cell marked as “DO NOT WRITE ANYTHING HERE.”
# - Replace the line "raise NotImplementedError()" with your code in each question cell.
# - Run all cells from top to bottom before submission.
# - Ensure that all code executes without errors and all required outputs appear correctly.
# - Save your notebook after completing all tasks.
# - Submit only the .ipynb file as your final solution.
# - Failure to follow these instructions may result in deduction of marks.
#
# File Naming Convention:
# - Your notebook must be named as:
# name_serialNumber.ipynb
# - Example:
# If your name is Rahul Kumar Sharma and your serial number is 30, then your file name should be:
# rahul_kumar_sharma_30.ipynb

# %% [markdown]
# ### Step 1: Import libraries and dataset
#
# Run the following cell to import the necessary libraries and load the dataset.

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the dataset from the CSV file
try:
    df = pd.read_csv('student_performance.csv')
    print("Dataset loaded successfully! Here are the first 5 rows:")
    display(df.head())
except FileNotFoundError:
    print("Error: 'student_performance.csv' not found.")
    print("Please make sure the CSV file is in the same directory as this notebook.")
# Out:
# Dataset loaded successfully! Here are the first 5 rows:
#    ID  Age  Study_Hours  Exam_Score
# 0   1   24         7.28        71.0
# 1   2   21         5.82        99.1
# 2   3   22         3.79        55.4
# 3   4   24         8.32        85.1
# 4   5   20         7.16        98.3

# %% [markdown]
# ### Question 1: Calculate the Mean Score (2 marks)
#
# Calculate the **mean** of the `Exam_Score` column. Assign the result to the variable `mean_score`.

# %%
mean_score = df['Exam_Score'].mean()
print(mean_score)
# Out:
# 77.4134

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 2: Calculate the Median Score (2 marks)
#
# Calculate the **median** of the `Exam_Score` column. Assign the result to the variable `median_score`.

# %%
median_score = df['Exam_Score'].median()
print(median_score)
# Out:
# 79.69999999999999

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 3: Calculate the Variance (2 marks)
#
# Calculate the **sample variance** of the `Exam_Score` column. Assign the result to the variable `variance_score`.

# %%
variance_score = df['Exam_Score'].var()
print(variance_score)
# Out:
# 325.4778983383398

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 4: Calculate the Standard Deviation (3 marks)
#
# Calculate the **standard deviation** of the `Exam_Score` column. Assign the result to the variable `std_dev_score`.

# %%
std_dev_score = df['Exam_Score'].std()
print(std_dev_score)
# Out:
# 18.041006023455004

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 5: Find the Correlation Coefficient (3 marks)
#
# Find the **correlation coefficient** between `Study_Hours` and `Exam_Score`. Assign the result to the variable `correlation_study_exam`.

# %%
correlation_study_exam = df['Study_Hours'].corr(df['Exam_Score'])
print(correlation_study_exam)
# Out:
# 0.9145158569596957

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 6: Find Average Score by Age (3 marks)
#
# Find the average `Exam_Score` for each `Age` group. The result should be a pandas Series. Assign this Series to the variable `avg_score_by_age`.

# %%
avg_score_by_age = df.groupby('Age').mean()['Exam_Score']
print(avg_score_by_age)
# Out:
# Age
# 18    75.039098
# 19    77.485470
# 20    77.861062
# 21    78.809589
# 22    77.714400
# 23    79.300000
# 24    76.736134
# 25    76.538060
# Name: Exam_Score, dtype: float64

# %%
# DO NOT WRITE ANYTHING HERE

# %% [markdown]
# ### Question 7: Visualization
# Create a scatter plot showing the relationship between `Study_Hours` and `Exam_Score`.
# Label the axes and give an appropriate title.

# %%
import matplotlib.pyplot as plt
plt.scatter(df['Study_Hours'], df['Exam_Score'], color = '#47d1cc')
plt.xlabel('Study Hours')
plt.ylabel('Exam Score')
plt.title('Scatter Plot of Study Hours vs Exam Score')
plt.grid(True)
plt.show()

# %% [markdown]
# ### End of Assignment
#
# Please make sure all your code cells have been executed and outputs are visible before submitting.
